# %% [markdown]
# <a href="https://colab.research.google.com/github/ranasaharshsingh/Generative-Ai/blob/main/Chat_Bot_Demp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-genai

# %%
from google import genai
import os

# %%
api_key='AIzaSyBMnHsyKmYRSRk-5-pomDufftOpbpJUWNk'
client = genai.Client(api_key=api_key)

# %%
print("--Gen Ai Tester -- type exit to quit")
while True:
  user_prompt = input("\nUser:")
  if user_prompt.lower() in ['exit','quit']:
    break
  try:
    response = client.models.generate_content(
        model = 'gemini-2.5-flash',
        contents = user_prompt
    )
    print(f"Ai:{response.text}")
  except Exception as e:
    print(f"Error:{e}")
# Out:
# --Gen Ai Tester -- type exit to quit
#
# User:quit
