# %% [markdown]
# <a href="https://colab.research.google.com/github/ranasaharshsingh/Generative-Ai/blob/main/Img_to_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-generativeai pillow

# %%
import google.generativeai as genai
from PIL import Image

# %%
genai.configure(api_key="AIzaSyA9saBqowD_Sfue2qBI1L4PM6kgEgaCdCY")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
from google.colab import files
uploaded = files.upload()

image_path = list(uploaded.keys())[0]
image = Image.open(image_path)
display(image)
# Out:
#      <input type="file" id="files-9a0eae64-4910-40b9-9a36-2cd71bf30f60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a0eae64-4910-40b9-9a36-2cd71bf30f60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
response = model.generate_content(
    [
        "Describe this image in detail",
        image
    ]
)

print(response.text)
# Out:
# This image is a brightly lit, professional headshot of a young woman smiling directly at the viewer.
#
# **Subject:**
# *   **Demographics:** The subject is a young to middle-aged woman with olive or warm-toned skin.
# *   **Hair:** She has long, voluminous dark brown hair with soft waves. It's parted on her left side and cascades over her shoulders, framing her face. The hair appears thick and healthy.
# *   **Face:**
#     *   **Expression:** Her most prominent feature is a wide, genuine, and radiant smile that lights up her face. Her mouth is open, revealing a full set of straight, white teeth.
#     *   **Eyes:** Her dark eyes (likely brown or hazel) are also smiling, with small crinkles at the corners, conveying warmth and approachability. Her eyebrows are dark, well-defined, and naturally arched.
#     *   **Nose:** She has a straight nose of medium size.
#     *   **Cheeks:** Her cheeks are raised due to her smile, accentuating her cheekbones.
# ...

# %%
response = model.generate_content(
    [
        "Extract all readable text from this image",
        image
    ]
)
print(response.text)
# Out:
# There is no readable text in this image.

# %%
response = model.generate_content(
    [
        "What objects are present in this image?",
        image
    ]
)
print(response.text)
# Out:
# The primary objects present in this image are:
#
# 1.  **A woman** (the main subject)
# 2.  **A dark blue blazer/jacket** (worn by the woman)
# 3.  **A white top/shirt** (visible underneath the blazer)
# 4.  **A plain, light-colored background** (likely a wall or studio backdrop)
