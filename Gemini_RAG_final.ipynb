# %% [markdown]
# <a href="https://colab.research.google.com/github/ranasaharshsingh/Generative-Ai/blob/main/Gemini_RAG_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-text-splitters

# %%
# !pip install -q langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 1.5 MB/s eta 0:00:00

# %%
# !pip uninstall -y google-auth requests
# !pip install -q google-auth==2.43.0 requests==2.32.4
# Out:
# Found existing installation: google-auth 2.47.0
# Uninstalling google-auth-2.47.0:
#   Successfully uninstalled google-auth-2.47.0
# Found existing installation: requests 2.32.4
# Uninstalling requests-2.32.4:
#   Successfully uninstalled requests-2.32.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.1/223.1 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 2.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.43.0 which is incompatible.
# google-genai 1.60.0 requires google-auth[requests]<3.0.0,>=2.47.0, but you have google-auth 2.43.0 which is incompatible.
# google-auth-oauthlib 1.2.4 requires google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0, but you have google-auth 2.43.0 which is incompatible.
# ...

# %%
# !pip install -q google-generativeai langchain langchain-community faiss-cpu pypdf python-docx
# !pip install requests==2.32.4
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 73.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.1/329.1 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.43.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# !pip uninstall -y langchain langchain-community
# Out:
# Found existing installation: langchain 1.2.7
# Uninstalling langchain-1.2.7:
#   Successfully uninstalled langchain-1.2.7
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1

# %%
# !pip install -q langchain langchain-community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 3.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.43.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# google-genai 1.60.0 requires google-auth[requests]<3.0.0,>=2.47.0, but you have google-auth 2.43.0 which is incompatible.
# google-cloud-aiplatform 1.135.0 requires google-auth<3.0.0,>=2.47.0, but you have google-auth 2.43.0 which is incompatible.
# google-adk 1.23.0 requires google-auth>=2.47.0, but you have google-auth 2.43.0 which is incompatible.

# %%
from langchain_community.document_loaders import PyPDFLoader
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
import os
import google.generativeai as genai # Explicitly import google.generativeai here

os.environ["GOOGLE_API_KEY"] = "Enter your own api key "
genai.configure(api_key=os.environ["Enter your own api key "])
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3805802904.py in <cell line: 0>()
#       3
#       4 os.environ["GOOGLE_API_KEY"] = "AIzaSyA9saBqowD_Sfue2qBI1L4PM6kgEgaCdCY"
# ----> 5 genai.configure(api_key=os.environ["AIzaSyA9saBqowD_Sfue2qBI1L4PM6kgEgaCdCY"])
#
# /usr/lib/python3.12/os.py in __getitem__(self, key)
#
# KeyError: 'AIzaSyA9saBqowD_Sfue2qBI1L4PM6kgEgaCdCY'

# %%
from google.colab import files

uploaded = files.upload()

# %%
#copy the path from the left side after uploading the document
loader = PyPDFLoader("copy the path from left side: 2nd last option")
documents = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print(f"Total chunks created: {len(chunks)}")

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = FAISS.from_documents(chunks, embeddings)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-flash",
    temperature=0.3
)

# %%
print(llm.invoke("Say hello in two sentence"))

# %%
def ask_question(query):
    # 1. Retrieve relevant chunks
    docs = vectorstore.similarity_search(query, k=2)

    context = "\n\n".join([doc.page_content for doc in docs])

    # 2. Create prompt
    prompt = f"""
You are an AI assistant.
Answer the question strictly using the context below.
If the answer is not in the context, say "Answer not found in the document."

Context:
{context}

Question:
{query}

Answer:
"""

    # 3. Ask Gemini
    response = llm.invoke(prompt)
    return response.content

# %%
print(ask_question(""))

# %%
vectorstore.similarity_search("introduction", k=2)

# %%
print(len(chunks))
